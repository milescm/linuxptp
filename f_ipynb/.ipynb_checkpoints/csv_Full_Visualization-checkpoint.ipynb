# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('../f_csv/ptpTime3.csv')

# %%
df.drop(['Unnamed: 0'],axis='columns',inplace=True)

# %%
df.head()
# Out:
#    __REALTIME_TIMESTAMP  __MONOTONIC_TIMESTAMP  Master Offset  Frequency  \
# 0      1595384939213303           144357253782        -463383      20296
# 1      1595384940214432           144358254910        -463583      20096
# 2      1595384941214901           144359255379           -819      19277
# 3      1595384942216036           144360256514           -750      19100
# 4      1595384943216513           144361256991          -6788      12837
#
#    Path Delay
# 0       24813
# 1       24852
# 2       24852
# 3       24852
# 4       24813

# %%
# Add abs master offset column to df_deleteErrdf, df, errdf

absMasterOffset = []

absMasterOffset = df['Master Offset'].abs()

df['Abs Master Offset'] = absMasterOffset

# %%
df.describe()
# Out:
#        __REALTIME_TIMESTAMP  __MONOTONIC_TIMESTAMP  Master Offset  \
# count          2.630000e+02           2.630000e+02     263.000000
# mean           1.595385e+15           1.444884e+11   -3529.269962
# std            7.613682e+07           7.613682e+07   40361.787493
# min            1.595385e+15           1.443573e+11 -463583.000000
# 25%            1.595385e+15           1.444228e+11    -415.000000
# 50%            1.595385e+15           1.444884e+11       9.000000
# 75%            1.595385e+15           1.445539e+11     351.000000
# max            1.595385e+15           1.446195e+11    7625.000000
#
#           Frequency    Path Delay  Abs Master Offset
# count    263.000000    263.000000         263.000000
# mean   19734.958175  24849.768061        4176.190114
# std     1150.756251    128.687663       40299.752433
# min    12837.000000  24573.000000           5.000000
# 25%    19415.000000  24759.000000         188.500000
# 50%    19763.000000  24845.000000         386.000000
# 75%    20077.000000  24933.000000         760.500000
# max    25214.000000  25146.000000      463583.000000

# %%
f, axes = plt.subplots(1,2, figsize = (20,15))

#Convergence index : 36, Offset = -193

sns.lineplot(x = "__REALTIME_TIMESTAMP", y = "Master Offset", data = df[:37], ax=axes[0])
sns.lineplot(x = "__REALTIME_TIMESTAMP", y = "Abs Master Offset", data = df[:37], ax = axes[1])

# %%
sns.relplot(x = "__REALTIME_TIMESTAMP", y = "Master Offset", data = df[27:47])
sns.relplot(x = "__REALTIME_TIMESTAMP", y = "Abs Master Offset", data = df[27:47])

# %%
# f, axes = plt.subplots(1,2, figsize = (16,10))
# sns.boxplot(y='Master Offset', data = df, palette="Paired", ax = axes[0])
# sns.boxplot(y='Abs Master Offset', data = df, palette="Paired", ax = axes[1])

# %%
# sns.distplot(df['Master Offset'])

# %%
# sns.distplot(df['Abs Master Offset'])

# %%
sns.jointplot(x='__REALTIME_TIMESTAMP', y = 'Master Offset', data = df, kind = "kde")
sns.jointplot(x='__REALTIME_TIMESTAMP', y = 'Abs Master Offset', data = df, kind = "kde")
